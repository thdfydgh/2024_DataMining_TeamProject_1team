# %% [markdown]
# # 서울시 교통사고 상해예측 & 위험 요인 분석

# %% [markdown]
# 2022년도 데이터를 활용해 2023년도 교통사고 상해 예측

# %% [markdown]
# ## 데이터 전처리

# %% [markdown]
# #### Data load

# %%
import pandas as pd

train = pd.read_csv(r"C:\Users\thdfy\OneDrive\바탕 화면\Datamining_Teampro\data\2022서울시교통사고현황-데이터셋.csv",encoding = 'euc-kr')
test = pd.read_csv(r"C:\Users\thdfy\OneDrive\바탕 화면\Datamining_Teampro\data\2023서울시교통사고현황-데이터셋.csv",encoding = 'euc-kr')

# %%
train['ECLO'] = train['중상자수'] * 5 + train['경상자수'] * 3 + train['부상신고자수']
test['ECLO'] = test['중상자수'] * 5 + test['경상자수'] * 3 + test['부상신고자수']

# %%
train.drop(columns=['사고번호'], inplace = True)
test.drop(columns=['사고번호'], inplace = True)

# %%
train['사고유형'] = train['사고유형'].str.split(' - ').str[0]
test['사고유형'] = test['사고유형'].str.split(' - ').str[0]

# %%
train['사고유형'].value_counts()
# Out:
# 사고유형
# 차대차     24898
# 차대사람     7807
# 차량단독      993
# Name: count, dtype: int64

# %%
train['사망자수'].value_counts()
# Out:
# 사망자수
# 0    33483
# 1      209
# 2        6
# Name: count, dtype: int64

# %%
test['ECLO'].mean()
# Out:
# 4.282038389873118

# %%
train['중상자수'].value_counts()
# Out:
# 중상자수
# 0    26479
# 1     6794
# 2      357
# 3       51
# 4       11
# 6        3
# 5        2
# 7        1
# Name: count, dtype: int64

# %%
train['경상자수'].value_counts()
# Out:
# 경상자수
# 1     19667
# 0      8137
# 2      4146
# 3      1118
# 4       387
# 5       139
# 6        50
# 7        18
# 8        13
# 9         7
# 10        6
# 11        3
# 13        3
# 12        2
# 17        1
# 25        1
# Name: count, dtype: int64

# %%
train['부상신고자수'].value_counts()
# Out:
# 부상신고자수
# 0    30796
# 1     2649
# 2      197
# 3       37
# 4       11
# 5        5
# 6        2
# 7        1
# Name: count, dtype: int64

# %%
train['법규위반'].value_counts()
# Out:
# 법규위반
# 안전운전불이행      19833
# 안전거리미확보       4447
# 신호위반          3783
# 기타            1379
# 보행자보호의무위반     1218
# 교차로운행방법위반     1081
# 중앙선침범          750
# 직진우회전진행방해      533
# 차로위반           422
# 불법유턴           252
# Name: count, dtype: int64

# %% [markdown]
# 예측 시점에 알 수 없는 정보들은 삭제. <br>
# 예측 시점에 알 수 있는 정보 : 사고일시, 요일, 기상상태, 시군구, 도로형태, 노면상태, 사고유형
# 예측 시점에 알 수 없는 정보:
#  '사고내용', '사망자수', '중상자수', '경상자수', '부상신고자수',
#  '가해운전자 차종', '가해운전자 성별',
# '가해운전자 연령', '가해운전자 상해정도',
# '피해운전자 차종', '피해운전자 성별', '피해운전자 연령',
# '피해운전자 상해정도'

# %%
test_drop = ['사고내용', '사망자수', '중상자수', '경상자수', '부상신고자수', '법규위반',
 '가해운전자 차종', '가해운전자 성별',
'가해운전자 연령', '가해운전자 상해정도',
'피해운전자 차종', '피해운전자 성별','피해운전자 연령',
'피해운전자 상해정도']
test.drop(columns=test_drop, inplace = True)

# %%
test.columns
# Out:
# Index(['사고일시', '요일', '시군구', '사고유형', '노면상태', '기상상태', '도로형태', 'ECLO'], dtype='object')

# %%
train.columns
# Out:
# Index(['사고일시', '요일', '시군구', '사고내용', '사망자수', '중상자수', '경상자수', '부상신고자수', '사고유형',
#        '법규위반', '노면상태', '기상상태', '도로형태', '가해운전자 차종', '가해운전자 성별', '가해운전자 연령',
#        '가해운전자 상해정도', '피해운전자 차종', '피해운전자 성별', '피해운전자 연령', '피해운전자 상해정도', 'ECLO'],
#       dtype='object')

# %%
train.head()
# Out:
#               사고일시   요일             시군구    사고내용  사망자수  중상자수  경상자수  부상신고자수  \
# 0  2022년 1월 1일 00시  토요일  서울특별시 중구 충무로5가    경상사고     0     0     1       0
# 1  2022년 1월 1일 00시  토요일   서울특별시 송파구 신천동    중상사고     0     2     0       0
# 2  2022년 1월 1일 02시  토요일   서울특별시 금천구 독산동  부상신고사고     0     0     0       1
# 3  2022년 1월 1일 02시  토요일   서울특별시 강동구 천호동    경상사고     0     0     2       0
# 4  2022년 1월 1일 06시  토요일   서울특별시 강남구 역삼동    중상사고     0     1     0       0
#
#    사고유형       법규위반  ...        도로형태 가해운전자 차종 가해운전자 성별 가해운전자 연령 가해운전자 상해정도  \
# 0   차대차    안전운전불이행  ...    단일로 - 기타       승용        남      63세       상해없음
# 1  차대사람  보행자보호의무위반  ...    단일로 - 기타       승용        남      69세       상해없음
# 2  차량단독    안전운전불이행  ...    단일로 - 기타       이륜        남      24세       부상신고
# 3   차대차    안전운전불이행  ...    단일로 - 기타       승용        여      61세       상해없음
# 4  차대사람    안전운전불이행  ...  교차로 - 교차로안       승용        남      62세       상해없음
#
#   피해운전자 차종 피해운전자 성별 피해운전자 연령 피해운전자 상해정도 ECLO
# 0       승용        남      67세         경상    3
# 1      보행자        여      16세         중상   10
# 2      NaN      NaN      NaN        NaN    1
# 3       승용        남      61세         경상    6
# 4      보행자        여      61세         중상    5
#
# [5 rows x 22 columns]

# %% [markdown]
# ### 1. 날짜, 시간 정보 생성

# %%
time_pattern = r'(\d{4})년 (\d{1,2})월 (\d{1,2})일 (\d{1,2})시'

train[['연', '월', '일', '시간']] = train['사고일시'].str.extract(time_pattern)
train[['연', '월', '일', '시간']] = train[['연', '월', '일', '시간']].apply(pd.to_numeric)

test[['연', '월', '일', '시간']] = test['사고일시'].str.extract(time_pattern)
test[['연', '월', '일', '시간']] = test[['연', '월', '일', '시간']].apply(pd.to_numeric)

# %% [markdown]
# #### 1.1 공휴일 컬럼 생성

# %%
import pandas as pd
from pandas import Timestamp, DateOffset
from workalendar.asia import SouthKorea
# = 공휴일 column 추가 =
def is_holiday(year, month, day):
  cal = SouthKorea()
  return cal.is_holiday(Timestamp(year, month, day))

def classify_day(year, month, day):
  date = Timestamp(year, month, day)
  if date.dayofweek < 5 and not is_holiday(year, month, day):
    return 0
  else:
    return 1

train['Holiday'] = train.apply(lambda row: classify_day(row['연'], row['월'], row['일']), axis=1)
train.drop(columns=['사고일시','일','연'], inplace = True) # 정보 추출이 완료된 '사고일시','일','요일','연' 컬럼은 제거합니다

test['Holiday'] = test.apply(lambda row: classify_day(row['연'], row['월'], row['일']), axis=1)
test.drop(columns=['사고일시','일','연'], inplace = True) # 정보 추출이 완료된 '사고일시','일','요일','연' 컬럼은 제거합니다

# %% [markdown]
# #### 1.2 봄, 여름, 가을, 겨울, 기상학적으로 구분함

# %%
# == 봄, 여름, 가을, 겨울, 기상학적으로 구분함 ==
def categorize_season(month):
    if month in [3, 4, 5]:
        return '봄'

    elif month in [6, 7, 8]:
        return '여름'

    elif month in [9, 10, 11]:
        return '가을'

    else:
        return '겨울'

train['계절'] = train['월'].apply(categorize_season)
test['계절'] = test['월'].apply(categorize_season)

# %% [markdown]
# 1.3 출 퇴근 시간(공휴일까지 고려) ==  평일에는 7~9, 18~20시까지 출퇴근, 공휴일에는 18~22시까지 교통량 증가로 확인

# %%
def rush_hour(hour, holiday):
    if (holiday == 0 and hour in [7, 8, 9, 18, 19, 20]) or (holiday == 1 and hour in [18, 19, 20, 21, 22]):
        return "Rush"
    else:
        return "NoRush"

train['출퇴근'] = train.apply(lambda row: rush_hour(row['시간'], row['Holiday']), axis=1)  
test['출퇴근'] = test.apply(lambda row: rush_hour(row['시간'], row['Holiday']), axis=1)

# %% [markdown]
# ### 2. 시군구 분리

# %%
location_pattern = r'(\S+) (\S+) (\S+)'

train[['도시', '구', '동']] = train['시군구'].str.extract(location_pattern)
train = train.drop(columns=['시군구'])

test[['도시', '구', '동']] = test['시군구'].str.extract(location_pattern)
test = test.drop(columns=['시군구'])

# %% [markdown]
# ### 3. 도로형태 분리

# %%
road_pattern = r'(.+) - (.+)'
train[['도로형태1', '도로형태2']] = train['도로형태'].str.extract(road_pattern)
train = train.drop(columns=['도로형태'])
test[['도로형태1', '도로형태2']] = test['도로형태'].str.extract(road_pattern)
test = test.drop(columns=['도로형태'])

# %% [markdown]
# ### 4. 나이 변수 전처리

# %%
import numpy as np
def age_transform(x):
  try:
    ret = int(x.split('세')[0])
  except:
    ret = np.NaN

  return ret

# %%
train['가해운전자 연령'] = train['가해운전자 연령'].apply(lambda x:age_transform(x))
train['피해운전자 연령'] = train['피해운전자 연령'].apply(lambda x:age_transform(x))

# %% [markdown]
# #### 4.1 지역별 가해운전자 & 피해운전자 평균 연령 추출

# %%
age_mean = train[['도시','구','동','가해운전자 연령','피해운전자 연령']].groupby(['도시', '구','동']).mean()
age_mean.columns = ['가해운전자 평균연령','피해운전자 평균연령']

# %%
train = pd.merge(train, age_mean, how='left', on=['도시', '구','동'])
test = pd.merge(test, age_mean, how='left', on=['도시', '구','동'])

# %%
train.head()
# Out:
#     요일    사고내용  사망자수  중상자수  경상자수  부상신고자수  사고유형       법규위반 노면상태 기상상태  ...  \
# 0  토요일    경상사고     0     0     1       0   차대차    안전운전불이행   건조   맑음  ...
# 1  토요일    중상사고     0     2     0       0  차대사람  보행자보호의무위반   건조   맑음  ...
# 2  토요일  부상신고사고     0     0     0       1  차량단독    안전운전불이행   건조   맑음  ...
# 3  토요일    경상사고     0     0     2       0   차대차    안전운전불이행   건조   맑음  ...
# 4  토요일    중상사고     0     1     0       0  차대사람    안전운전불이행   건조   맑음  ...
#
#   Holiday  계절     출퇴근     도시    구      동  도로형태1 도로형태2  가해운전자 평균연령  피해운전자 평균연령
# 0       1  겨울  NoRush  서울특별시   중구  충무로5가    단일로    기타   69.666667   54.000000
# 1       1  겨울  NoRush  서울특별시  송파구    신천동    단일로    기타   48.677852   43.947712
# 2       1  겨울  NoRush  서울특별시  금천구    독산동    단일로    기타   50.306818   47.347826
# 3       1  겨울  NoRush  서울특별시  강동구    천호동    단일로    기타   51.441441   47.843750
# 4       1  겨울  NoRush  서울특별시  강남구    역삼동    교차로  교차로안   45.877792   42.001300
#
# [5 rows x 31 columns]

# %%
test.head()
# Out:
#     요일  사고유형 노면상태 기상상태  ECLO  월  시간  Holiday  계절     출퇴근     도시    구      동  \
# 0  일요일   차대차   건조   맑음     6  1   0        1  겨울  NoRush  서울특별시  성동구  성수동2가
# 1  일요일   차대차   건조   흐림     3  1   0        1  겨울  NoRush  서울특별시  관악구    신림동
# 2  일요일  차대사람   건조   맑음     5  1   1        1  겨울  NoRush  서울특별시  은평구    대조동
# 3  일요일   차대차   건조   맑음     5  1   2        1  겨울  NoRush  서울특별시  성북구  보문동7가
# 4  일요일   차대차   건조   맑음     3  1   2        1  겨울  NoRush  서울특별시  동작구    대방동
#
#   도로형태1 도로형태2  가해운전자 평균연령  피해운전자 평균연령
# 0   교차로  교차로안   49.074324   44.646259
# 1   교차로  교차로안   48.111283   43.913112
# 2   단일로    기타   47.247059   47.564706
# 3   교차로  교차로안   49.357143   41.142857
# 4   단일로    기타   48.521429   46.840909

# %%
train.columns
# Out:
# Index(['요일', '사고내용', '사망자수', '중상자수', '경상자수', '부상신고자수', '사고유형', '법규위반', '노면상태',
#        '기상상태', '가해운전자 차종', '가해운전자 성별', '가해운전자 연령', '가해운전자 상해정도', '피해운전자 차종',
#        '피해운전자 성별', '피해운전자 연령', '피해운전자 상해정도', 'ECLO', '월', '시간', 'Holiday',
#        '계절', '출퇴근', '도시', '구', '동', '도로형태1', '도로형태2', '가해운전자 평균연령',
#        '피해운전자 평균연령'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['요일', '사고유형', '노면상태', '기상상태', 'ECLO', '월', '시간', 'Holiday', '계절', '출퇴근',
#        '도시', '구', '동', '도로형태1', '도로형태2', '가해운전자 평균연령', '피해운전자 평균연령'],
#       dtype='object')

# %% [markdown]
# ### 5. 불필요한 열 제거, 상관계수가 높은 열 제거

# %%
train_drop = [ '사고내용', '사망자수', '중상자수', '경상자수', '부상신고자수',
        '가해운전자 차종', '가해운전자 성별', '가해운전자 연령', '가해운전자 상해정도', '피해운전자 차종',
       '피해운전자 성별', '피해운전자 연령', '피해운전자 상해정도',  '월', '시간', 
         '도시','법규위반' ]
train.drop(columns=train_drop, inplace = True)

# %%
test_drop = ['월', '시간', '도시']
test.drop(columns=test_drop, inplace = True)

# %%
train.columns
# Out:
# Index(['요일', '사고유형', '노면상태', '기상상태', 'ECLO', 'Holiday', '계절', '출퇴근', '구', '동',
#        '도로형태1', '도로형태2', '가해운전자 평균연령', '피해운전자 평균연령'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['요일', '사고유형', '노면상태', '기상상태', 'ECLO', 'Holiday', '계절', '출퇴근', '구', '동',
#        '도로형태1', '도로형태2', '가해운전자 평균연령', '피해운전자 평균연령'],
#       dtype='object')

# %%
train.shape, test.shape
# Out:
# ((33698, 14), (33811, 14))

# %% [markdown]
# ### 인코딩

# %%
# # == 기상상태, 노면상태, 계절 -> 원핫인코딩 ==
# train = pd.get_dummies(train, columns = ['기상상태', '노면상태', '계절', '출퇴근'])
# test = pd.get_dummies(test, columns = ['기상상태', '노면상태', '계절', '출퇴근'])

# %%
# from sklearn.preprocessing import LabelEncoder

# categorical_features = list(train.dtypes[train.dtypes == "object"].index)
# # 추출된 문자열 변수 확인
# display(categorical_features)

# for i in categorical_features:
#     print(i)
#     le = LabelEncoder()
#     le=le.fit(train[i])
#     train[i]=le.transform(train[i])

#     for case in np.unique(test[i]):
#         if case not in le.classes_:
#             print('test case is not in classes')
#             le.classes_ = np.append(le.classes_, case)
#     test[i]=le.transform(test[i])

# display(train.head())
# display(test.head())

# %% [markdown]
# ## 모델 예측

# %%
train
# Out:
#         요일  사고유형 노면상태 기상상태  ECLO  Holiday  계절     출퇴근    구      동 도로형태1  \
# 0      토요일   차대차   건조   맑음     3        1  겨울  NoRush   중구  충무로5가   단일로
# 1      토요일  차대사람   건조   맑음    10        1  겨울  NoRush  송파구    신천동   단일로
# 2      토요일  차량단독   건조   맑음     1        1  겨울  NoRush  금천구    독산동   단일로
# 3      토요일   차대차   건조   맑음     6        1  겨울  NoRush  강동구    천호동   단일로
# 4      토요일  차대사람   건조   맑음     5        1  겨울  NoRush  강남구    역삼동   교차로
# ...    ...   ...  ...  ...   ...      ...  ..     ...  ...    ...   ...
# 33693  토요일   차대차   건조   맑음     3        1  겨울  NoRush  광진구    군자동   단일로
# 33694  토요일   차대차   건조   맑음     3        1  겨울  NoRush  마포구    염리동   단일로
# 33695  토요일   차대차   건조   맑음     1        1  겨울  NoRush  중랑구    면목동   단일로
# 33696  토요일   차대차   건조   맑음     3        1  겨울  NoRush  구로구    구로동   교차로
# 33697  토요일   차대차   건조   맑음     6        1  겨울  NoRush  양천구     목동   교차로
#
#        도로형태2  가해운전자 평균연령  피해운전자 평균연령
# 0         기타   69.666667   54.000000
# 1         기타   48.677852   43.947712
# 2         기타   50.306818   47.347826
# 3         기타   51.441441   47.843750
# 4       교차로안   45.877792   42.001300
# ...      ...         ...         ...
# 33693     기타   48.794118   43.927536
# 33694     기타   44.304348   38.565217
# 33695     기타   50.073684   48.165957
# 33696  교차로부근   50.936567   45.836502
# 33697  교차로부근   47.843602   43.026005
#
# [33698 rows x 14 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from catboost import CatBoostRegressor, Pool
from sklearn.metrics import mean_squared_log_error, r2_score
import matplotlib.pyplot as plt


# 결측값 처리 (결측값이 있는 경우)
train = train.fillna(0)
test = test.fillna(0)

# 사고 유형별로 데이터셋 분할 및 샘플링
train1 = train[train["사고유형"] == "차량단독"]  # 차량단독
train2 = train[train["사고유형"] == "차대차"]  # 차대차
train3 = train[train["사고유형"] == "차대사람"]  # 차대사람

test1 = test[test["사고유형"] == "차량단독"]
test2 = test[test["사고유형"] == "차대차"]
test3 = test[test["사고유형"] == "차대사람"]

# 데이터셋 분할 함수 정의
def split_data(df, target):
    X = df.drop(columns=[target])
    y = df[target]
    return X, y

X_train1, y_train1 = split_data(train1, 'ECLO')
X_train2, y_train2 = split_data(train2, 'ECLO')
X_train3, y_train3 = split_data(train3, 'ECLO')

X_test1, y_test1 = split_data(test1, 'ECLO')
X_test2, y_test2 = split_data(test2, 'ECLO')
X_test3, y_test3 = split_data(test3, 'ECLO')
# RMSLE 계산 함수 정의
def rmsle(y_true, y_pred):
    return np.sqrt(mean_squared_log_error(y_true, y_pred))

# CatBoost 모델 학습 및 평가 함수 정의
def train_and_evaluate(X_train, y_train, X_test, y_test, params, cat_features):
    model = CatBoostRegressor(random_seed=42, thread_count=-1, **params)
    model.fit(X_train, y_train, cat_features=cat_features, verbose=0)
    y_pred_test = model.predict(X_test)

    rmsle_value = rmsle(y_test, y_pred_test)
    r2_value = r2_score(y_test, y_pred_test)

    return model, rmsle_value, r2_value

# 범주형 피처 인덱스 추출
cat_features1 = np.where(X_train1.dtypes == object)[0]
cat_features2 = np.where(X_train2.dtypes == object)[0]
cat_features3 = np.where(X_train3.dtypes == object)[0]

# CatBoost 파라미터 설정
catboost_params1 = {
    'iterations': 6111,
    'od_wait': 609,
    'learning_rate': 0.04119744178592561,
    'reg_lambda': 5.488592836608496,
    'subsample': 0.9203846250162546,
    'random_strength': 14.883401811234684,
    'depth': 5,
    'min_data_in_leaf': 3,
    'leaf_estimation_iterations': 10,
    'bagging_temperature': 0.01789129283627206,
    'colsample_bylevel': 0.5972283837388589
}

catboost_params2 = {
    'iterations': 13411,
    'od_wait': 1144,
    'learning_rate': 0.021727882868213363,
    'reg_lambda': 21.015616790374914,
    'subsample': 0.878372685297051,
    'random_strength': 36.58060974949341,
    'depth': 7,
    'min_data_in_leaf': 7,
    'leaf_estimation_iterations': 9,
    'bagging_temperature': 0.05180927511974106,
    'colsample_bylevel': 0.579406682782964
}

catboost_params3 = {
    'iterations': 6500,
    'od_wait': 1641,
    'learning_rate': 0.039883471636645535,
    'reg_lambda': 8.723928583044282,
    'subsample': 0.8317293182421713,
    'random_strength': 22.481544108255296,
    'depth': 5,
    'min_data_in_leaf': 9,
    'leaf_estimation_iterations': 9,
    'bagging_temperature': 0.022614197973049137,
    'colsample_bylevel': 0.7882803255907027
}

# 모델 학습 및 평가
model1, rmsle1, r21 = train_and_evaluate(X_train1, y_train1, X_test1, y_test1, catboost_params1, cat_features1)
model2, rmsle2, r22 = train_and_evaluate(X_train2, y_train2, X_test2, y_test2, catboost_params2, cat_features2)
model3, rmsle3, r23 = train_and_evaluate(X_train3, y_train3, X_test3, y_test3, catboost_params3, cat_features3)

print(f'차량단독 사고 유형 - RMSLE: {rmsle1}, R²: {r21}')
print(f'차대차 사고 유형 - RMSLE: {rmsle2}, R²: {r22}')
print(f'차대사람 사고 유형 - RMSLE: {rmsle3}, R²: {r23}')

# 예측값을 test 데이터프레임에 추가
test1['predict'] = model1.predict(X_test1)
test2['predict'] = model2.predict(X_test2)
test3['predict'] = model3.predict(X_test3)

# Feature Importance 시각화
def plot_feature_importance(model, X_train, title):
    importance = model.get_feature_importance()
    indices = np.argsort(importance)[::-1]
    plt.figure(figsize=(12, 6))
    plt.title(f'Feature Importance - {title}')
    plt.bar(range(X_train.shape[1]), importance[indices], align='center')
    plt.xticks(range(X_train.shape[1]), [X_train.columns[i] for i in indices], rotation=90)
    plt.tight_layout()
    plt.show()

plot_feature_importance(model1, X_train1, '차량단독 사고 유형')
plot_feature_importance(model2, X_train2, '차대차 사고 유형')
plot_feature_importance(model3, X_train3, '차대사람 사고 유형')

# RMSLE와 R² 값을 계산하여 출력
rmsle_test1 = rmsle(y_test1, test1['predict'])
r2_test1 = r2_score(y_test1, test1['predict'])
print(f'차량단독 사고 유형 (Test) - RMSLE: {rmsle_test1}, R²: {r2_test1}')

rmsle_test2 = rmsle(y_test2, test2['predict'])
r2_test2 = r2_score(y_test2, test2['predict'])
print(f'차대차 사고 유형 (Test) - RMSLE: {rmsle_test2}, R²: {r2_test2}')

rmsle_test3 = rmsle(y_test3, test3['predict'])
r2_test3 = r2_score(y_test3, test3['predict'])
print(f'차대사람 사고 유형 (Test) - RMSLE: {rmsle_test3}, R²: {r2_test3}')
# Out:
# 차량단독 사고 유형 - RMSLE: 0.442677465679094, R²: -0.18908714455777553
# 차대차 사고 유형 - RMSLE: 0.45248285610664296, R²: -0.023345728404085886
# 차대사람 사고 유형 - RMSLE: 0.3630530877523034, R²: -0.04217546354346635
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:108: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test1['predict'] = model1.predict(X_test1)
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:109: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test2['predict'] = model2.predict(X_test2)
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test3['predict'] = model3.predict(X_test3)
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 50836 (\N{HANGUL SYLLABLE YO}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 54588 (\N{HANGUL SYLLABLE PI}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 54644 (\N{HANGUL SYLLABLE HAE}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 50868 (\N{HANGUL SYLLABLE UN}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 47161 (\N{HANGUL SYLLABLE RYEONG}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 44228 (\N{HANGUL SYLLABLE GYE}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 51208 (\N{HANGUL SYLLABLE JEOL}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 54805 (\N{HANGUL SYLLABLE HYEONG}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 53468 (\N{HANGUL SYLLABLE TAE}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 45432 (\N{HANGUL SYLLABLE NO}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 47732 (\N{HANGUL SYLLABLE MYEON}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 52636 (\N{HANGUL SYLLABLE CUL}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 53748 (\N{HANGUL SYLLABLE TOE}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 44540 (\N{HANGUL SYLLABLE GEUN}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 45800 (\N{HANGUL SYLLABLE DAN}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 46021 (\N{HANGUL SYLLABLE DOG}) missing from current font.
#   plt.tight_layout()
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 45800 (\N{HANGUL SYLLABLE DAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 46021 (\N{HANGUL SYLLABLE DOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54805 (\N{HANGUL SYLLABLE HYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50836 (\N{HANGUL SYLLABLE YO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54588 (\N{HANGUL SYLLABLE PI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54644 (\N{HANGUL SYLLABLE HAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50868 (\N{HANGUL SYLLABLE UN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47161 (\N{HANGUL SYLLABLE RYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44228 (\N{HANGUL SYLLABLE GYE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51208 (\N{HANGUL SYLLABLE JEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 53468 (\N{HANGUL SYLLABLE TAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 45432 (\N{HANGUL SYLLABLE NO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47732 (\N{HANGUL SYLLABLE MYEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 52636 (\N{HANGUL SYLLABLE CUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 53748 (\N{HANGUL SYLLABLE TOE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44540 (\N{HANGUL SYLLABLE GEUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 50836 (\N{HANGUL SYLLABLE YO}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 54644 (\N{HANGUL SYLLABLE HAE}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 50868 (\N{HANGUL SYLLABLE UN}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 47161 (\N{HANGUL SYLLABLE RYEONG}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 54588 (\N{HANGUL SYLLABLE PI}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 44228 (\N{HANGUL SYLLABLE GYE}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 51208 (\N{HANGUL SYLLABLE JEOL}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 54805 (\N{HANGUL SYLLABLE HYEONG}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 53468 (\N{HANGUL SYLLABLE TAE}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 45432 (\N{HANGUL SYLLABLE NO}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 47732 (\N{HANGUL SYLLABLE MYEON}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 52636 (\N{HANGUL SYLLABLE CUL}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 53748 (\N{HANGUL SYLLABLE TOE}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 44540 (\N{HANGUL SYLLABLE GEUN}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   plt.tight_layout()
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54805 (\N{HANGUL SYLLABLE HYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50836 (\N{HANGUL SYLLABLE YO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54644 (\N{HANGUL SYLLABLE HAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50868 (\N{HANGUL SYLLABLE UN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47161 (\N{HANGUL SYLLABLE RYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54588 (\N{HANGUL SYLLABLE PI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44228 (\N{HANGUL SYLLABLE GYE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51208 (\N{HANGUL SYLLABLE JEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 53468 (\N{HANGUL SYLLABLE TAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 45432 (\N{HANGUL SYLLABLE NO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47732 (\N{HANGUL SYLLABLE MYEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 52636 (\N{HANGUL SYLLABLE CUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 53748 (\N{HANGUL SYLLABLE TOE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44540 (\N{HANGUL SYLLABLE GEUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 50836 (\N{HANGUL SYLLABLE YO}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 54588 (\N{HANGUL SYLLABLE PI}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 54644 (\N{HANGUL SYLLABLE HAE}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 50868 (\N{HANGUL SYLLABLE UN}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 47161 (\N{HANGUL SYLLABLE RYEONG}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 44228 (\N{HANGUL SYLLABLE GYE}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 51208 (\N{HANGUL SYLLABLE JEOL}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 54805 (\N{HANGUL SYLLABLE HYEONG}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 53468 (\N{HANGUL SYLLABLE TAE}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 45432 (\N{HANGUL SYLLABLE NO}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 47732 (\N{HANGUL SYLLABLE MYEON}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 52636 (\N{HANGUL SYLLABLE CUL}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 53748 (\N{HANGUL SYLLABLE TOE}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 44540 (\N{HANGUL SYLLABLE GEUN}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   plt.tight_layout()
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_29192\3171522761.py:120: UserWarning: Glyph 46988 (\N{HANGUL SYLLABLE RAM}) missing from current font.
#   plt.tight_layout()
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 46988 (\N{HANGUL SYLLABLE RAM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54805 (\N{HANGUL SYLLABLE HYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50836 (\N{HANGUL SYLLABLE YO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54588 (\N{HANGUL SYLLABLE PI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54644 (\N{HANGUL SYLLABLE HAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50868 (\N{HANGUL SYLLABLE UN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47161 (\N{HANGUL SYLLABLE RYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44228 (\N{HANGUL SYLLABLE GYE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51208 (\N{HANGUL SYLLABLE JEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 53468 (\N{HANGUL SYLLABLE TAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 45432 (\N{HANGUL SYLLABLE NO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47732 (\N{HANGUL SYLLABLE MYEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 52636 (\N{HANGUL SYLLABLE CUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 53748 (\N{HANGUL SYLLABLE TOE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44540 (\N{HANGUL SYLLABLE GEUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# 차량단독 사고 유형 (Test) - RMSLE: 0.442677465679094, R²: -0.18908714455777553
# 차대차 사고 유형 (Test) - RMSLE: 0.45248285610664296, R²: -0.023345728404085886
# 차대사람 사고 유형 (Test) - RMSLE: 0.3630530877523034, R²: -0.04217546354346635

# %%
train['사고유형'].value_counts()
# Out:
# 사고유형
# 차대차     24898
# 차대사람     7807
# 차량단독      993
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
font_path = "c:/Windows/Fonts/malgun.ttf"  # Windows의 경우
fontprop = fm.FontProperties(fname=font_path, size=12)
plt.rc('font', family=fontprop.get_name())

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_log_error, r2_score
import matplotlib.pyplot as plt



# 결측값 처리 (결측값이 있는 경우)
train = train.fillna(0)
test = test.fillna(0)

# 사고 유형별로 데이터셋 분할 및 샘플링
train1 = train[train["사고유형"] == 2]  # 차량단독
train2 = train[train["사고유형"] == 1]  # 차대차
train3 = train[train["사고유형"] == 0]  # 차대사람

test1 = test[test["사고유형"] == 2]
test2 = test[test["사고유형"] == 1]
test3 = test[test["사고유형"] == 0]
# test1 = test[test["사고유형"] == 2].sample(n=300, random_state=42)  # 차량단독
# test2 = test[test["사고유형"] == 1].sample(n=5000, random_state=42)  # 차대차
# test3 = test[test["사고유형"] == 0].sample(n=2000, random_state=42)  # 차대사람

# 데이터셋 분할 함수 정의
def split_data(df, target):
    X = df.drop(columns=[target])
    y = df[target]
    return X, y

X_train1, y_train1 = split_data(train1, 'ECLO')
X_train2, y_train2 = split_data(train2, 'ECLO')
X_train3, y_train3 = split_data(train3, 'ECLO')

X_test1, y_test1 = split_data(test1, 'ECLO')
X_test2, y_test2 = split_data(test2, 'ECLO')
X_test3, y_test3 = split_data(test3, 'ECLO')

# RMSLE 계산 함수 정의
def rmsle(y_true, y_pred):
    return np.sqrt(mean_squared_log_error(y_true, y_pred))

# 모델 학습 및 평가 함수 정의
def train_and_evaluate(X_train, y_train, X_test, y_test):
    model = RandomForestRegressor(random_state=42)
    model.fit(X_train, y_train)
    y_pred_test = model.predict(X_test)

    rmsle_value = rmsle(y_test, y_pred_test)
    r2_value = r2_score(y_test, y_pred_test)

    return model, rmsle_value, r2_value

# 모델 학습 및 평가
model1, rmsle1, r21 = train_and_evaluate(X_train1, y_train1, X_test1, y_test1)
model2, rmsle2, r22 = train_and_evaluate(X_train2, y_train2, X_test2, y_test2)
model3, rmsle3, r23 = train_and_evaluate(X_train3, y_train3, X_test3, y_test3)

print(f'차량단독 사고 유형 - RMSLE: {rmsle1}, R²: {r21}')
print(f'차대차 사고 유형 - RMSLE: {rmsle2}, R²: {r22}')
print(f'차대사람 사고 유형 - RMSLE: {rmsle3}, R²: {r23}')

# 예측값을 test 데이터프레임에 추가
test1.loc[:, 'predict'] = model1.predict(X_test1)
test2.loc[:, 'predict'] = model2.predict(X_test2)
test3.loc[:, 'predict'] = model3.predict(X_test3)

# Feature Importance 시각화
def plot_feature_importance(model, X_train, title):
    importance = model.feature_importances_
    indices = np.argsort(importance)[::-1]
    plt.figure(figsize=(12, 6))
    plt.title(f'Feature Importance - {title}')
    plt.bar(range(X_train.shape[1]), importance[indices], align='center')
    plt.xticks(range(X_train.shape[1]), [X_train.columns[i] for i in indices], rotation=90)
    plt.tight_layout()
    plt.show()

plot_feature_importance(model1, X_train1, '차량단독 사고 유형')
plot_feature_importance(model2, X_train2, '차대차 사고 유형')
plot_feature_importance(model3, X_train3, '차대사람 사고 유형')

# RMSLE와 R² 값을 계산하여 출력
rmsle_test1 = rmsle(y_test1, test1['predict'])
r2_test1 = r2_score(y_test1, test1['predict'])
print(f'차량단독 사고 유형 (Test) - RMSLE: {rmsle_test1}, R²: {r2_test1}')

rmsle_test2 = rmsle(y_test2, test2['predict'])
r2_test2 = r2_score(y_test2, test2['predict'])
print(f'차대차 사고 유형 (Test) - RMSLE: {rmsle_test2}, R²: {r2_test2}')

rmsle_test3 = rmsle(y_test3, test3['predict'])
r2_test3 = r2_score(y_test3, test3['predict'])
print(f'차대사람 사고 유형 (Test) - RMSLE: {rmsle_test3}, R²: {r2_test3}')
# 차량단독 사고 유형 - RMSLE: 0.40470011594412897, R²: -0.2324461316191424
# 차대차 사고 유형 - RMSLE: 0.4896821512249026, R²: -0.25520933939111745
# 차대사람 사고 유형 - RMSLE: 0.3615198425497484, R²: -0.16971634566501748
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 56
#      53     return model, rmsle_value, r2_value
#      55 # 모델 학습 및 평가
# ---> 56 model1, rmsle1, r21 = train_and_evaluate(X_train1, y_train1, X_test1, y_test1)
#      57 model2, rmsle2, r22 = train_and_evaluate(X_train2, y_train2, X_test2, y_test2)
#      58 model3, rmsle3, r23 = train_and_evaluate(X_train3, y_train3, X_test3, y_test3)
#
# Cell In[44], line 47, in train_and_evaluate(X_train, y_train, X_test, y_test)
#      45 def train_and_evaluate(X_train, y_train, X_test, y_test):
#      46     model = RandomForestRegressor(random_state=42)
# ---> 47     model.fit(X_train, y_train)
#      48     y_pred_test = model.predict(X_test)
#      50     rmsle_value = rmsle(y_test, y_pred_test)
#
# File c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\sklearn\ensemble\_forest.py:363, in BaseForest.fit(self, X, y, sample_weight)
#     360 if issparse(y):
#     361     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 363 X, y = self._validate_data(
#     364     X,
#     365     y,
#     366     multi_output=True,
#     367     accept_sparse="csc",
#     368     dtype=DTYPE,
#     369     force_all_finite=False,
#     370 )
#     371 # _compute_missing_values_in_feature_mask checks if X has missing values and
#     372 # will raise an error if the underlying tree base estimator can't handle missing
#     373 # values. Only the criterion is required to determine if the tree supports
#     374 # missing values.
#     375 estimator = type(self.estimator)(criterion=self.criterion)
#
# File c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\sklearn\base.py:650, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648         y = check_array(y, input_name="y", **check_y_params)
#     649     else:
# --> 650         X, y = check_X_y(X, y, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
#
# File c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\sklearn\utils\validation.py:1263, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1258         estimator_name = _check_estimator_name(estimator)
#    1259     raise ValueError(
#    1260         f"{estimator_name} requires y to be passed, but the target y is None"
#    1261     )
# -> 1263 X = check_array(
#    1264     X,
#    1265     accept_sparse=accept_sparse,
#    1266     accept_large_sparse=accept_large_sparse,
#    1267     dtype=dtype,
#    1268     order=order,
#    1269     copy=copy,
#    1270     force_all_finite=force_all_finite,
#    1271     ensure_2d=ensure_2d,
#    1272     allow_nd=allow_nd,
#    1273     ensure_min_samples=ensure_min_samples,
#    1274     ensure_min_features=ensure_min_features,
#    1275     estimator=estimator,
#    1276     input_name="X",
#    1277 )
#    1279 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1281 check_consistent_length(X, y)
#
# File c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\sklearn\utils\validation.py:1072, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1070     n_samples = _num_samples(array)
#    1071     if n_samples < ensure_min_samples:
# -> 1072         raise ValueError(
#    1073             "Found array with %d sample(s) (shape=%s) while a"
#    1074             " minimum of %d is required%s."
#    1075             % (n_samples, array.shape, ensure_min_samples, context)
#    1076         )
#    1078 if ensure_min_features > 0 and array.ndim == 2:
#    1079     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0, 13)) while a minimum of 1 is required by RandomForestRegressor.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_squared_log_error, r2_score
import matplotlib.pyplot as plt

# 결측값 처리 (결측값이 있는 경우)
train = train.fillna(0)
test = test.fillna(0)

# 사고 유형별로 데이터셋 분할 및 샘플링
train1 = train[train["사고유형"] == 2]  # 차량단독
train2 = train[train["사고유형"] == 1]  # 차대차
train3 = train[train["사고유형"] == 0]  # 차대사람

test1 = test[test["사고유형"] == 2]
test2 = test[test["사고유형"] == 1]
test3 = test[test["사고유형"] == 0]

# 데이터셋 분할 함수 정의
def split_data(df, target):
    X = df.drop(columns=[target])
    y = df[target]
    return X, y

X_train1, y_train1 = split_data(train1, 'ECLO')
X_train2, y_train2 = split_data(train2, 'ECLO')
X_train3, y_train3 = split_data(train3, 'ECLO')

X_test1, y_test1 = split_data(test1, 'ECLO')
X_test2, y_test2 = split_data(test2, 'ECLO')
X_test3, y_test3 = split_data(test3, 'ECLO')

# RMSLE 계산 함수 정의
def rmsle(y_true, y_pred):
    return np.sqrt(mean_squared_log_error(y_true, y_pred))

# 모델 학습 및 평가 함수 정의
def train_and_evaluate(X_train, y_train, X_test, y_test):
    model = RandomForestRegressor(random_state=42)
    model.fit(X_train, y_train)
    y_pred_test = model.predict(X_test)

    mse_value = mean_squared_error(y_test, y_pred_test)
    mae_value = mean_absolute_error(y_test, y_pred_test)
    rmsle_value = rmsle(y_test, y_pred_test)
    r2_value = r2_score(y_test, y_pred_test)

    return model, mse_value, mae_value, rmsle_value, r2_value

# 모델 학습 및 평가
model1, mse1, mae1, rmsle1, r21 = train_and_evaluate(X_train1, y_train1, X_test1, y_test1)
model2, mse2, mae2, rmsle2, r22 = train_and_evaluate(X_train2, y_train2, X_test2, y_test2)
model3, mse3, mae3, rmsle3, r23 = train_and_evaluate(X_train3, y_train3, X_test3, y_test3)

print(f'차량단독 사고 유형 - MSE: {mse1}, MAE: {mae1}, RMSLE: {rmsle1}, R²: {r21}')
print(f'차대차 사고 유형 - MSE: {mse2}, MAE: {mae2}, RMSLE: {rmsle2}, R²: {r22}')
print(f'차대사람 사고 유형 - MSE: {mse3}, MAE: {mae3}, RMSLE: {rmsle3}, R²: {r23}')

# 예측값을 test 데이터프레임에 추가
test1.loc[:, 'predict'] = model1.predict(X_test1)
test2.loc[:, 'predict'] = model2.predict(X_test2)
test3.loc[:, 'predict'] = model3.predict(X_test3)

# Feature Importance 시각화
def plot_feature_importance(model, X_train, title):
    importance = model.feature_importances_
    indices = np.argsort(importance)[::-1]
    plt.figure(figsize=(12, 6))
    plt.title(f'Feature Importance - {title}')
    plt.bar(range(X_train.shape[1]), importance[indices], align='center')
    plt.xticks(range(X_train.shape[1]), [X_train.columns[i] for i in indices], rotation=90)
    plt.tight_layout()
    plt.show()

plot_feature_importance(model1, X_train1, '차량단독 사고 유형')
plot_feature_importance(model2, X_train2, '차대차 사고 유형')
plot_feature_importance(model3, X_train3, '차대사람 사고 유형')

# RMSLE와 R² 값을 계산하여 출력
rmsle_test1 = rmsle(y_test1, test1['predict'])
r2_test1 = r2_score(y_test1, test1['predict'])
print(f'차량단독 사고 유형 (Test) - RMSLE: {rmsle_test1}, R²: {r2_test1}')

rmsle_test2 = rmsle(y_test2, test2['predict'])
r2_test2 = r2_score(y_test2, test2['predict'])
print(f'차대차 사고 유형 (Test) - RMSLE: {rmsle_test2}, R²: {r2_test2}')

rmsle_test3 = rmsle(y_test3, test3['predict'])
r2_test3 = r2_score(y_test3, test3['predict'])
print(f'차대사람 사고 유형 (Test) - RMSLE: {rmsle_test3}, R²: {r2_test3}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 53
#      50     return model, mse_value, mae_value, rmsle_value, r2_value
#      52 # 모델 학습 및 평가
# ---> 53 model1, mse1, mae1, rmsle1, r21 = train_and_evaluate(X_train1, y_train1, X_test1, y_test1)
#      54 model2, mse2, mae2, rmsle2, r22 = train_and_evaluate(X_train2, y_train2, X_test2, y_test2)
#      55 model3, mse3, mae3, rmsle3, r23 = train_and_evaluate(X_train3, y_train3, X_test3, y_test3)
#
# Cell In[45], line 42, in train_and_evaluate(X_train, y_train, X_test, y_test)
#      40 def train_and_evaluate(X_train, y_train, X_test, y_test):
#      41     model = RandomForestRegressor(random_state=42)
# ---> 42     model.fit(X_train, y_train)
#      43     y_pred_test = model.predict(X_test)
#      45     mse_value = mean_squared_error(y_test, y_pred_test)
#
# File c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\sklearn\ensemble\_forest.py:363, in BaseForest.fit(self, X, y, sample_weight)
#     360 if issparse(y):
#     361     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 363 X, y = self._validate_data(
#     364     X,
#     365     y,
#     366     multi_output=True,
#     367     accept_sparse="csc",
#     368     dtype=DTYPE,
#     369     force_all_finite=False,
#     370 )
#     371 # _compute_missing_values_in_feature_mask checks if X has missing values and
#     372 # will raise an error if the underlying tree base estimator can't handle missing
#     373 # values. Only the criterion is required to determine if the tree supports
#     374 # missing values.
#     375 estimator = type(self.estimator)(criterion=self.criterion)
#
# File c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\sklearn\base.py:650, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648         y = check_array(y, input_name="y", **check_y_params)
#     649     else:
# --> 650         X, y = check_X_y(X, y, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
#
# File c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\sklearn\utils\validation.py:1263, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1258         estimator_name = _check_estimator_name(estimator)
#    1259     raise ValueError(
#    1260         f"{estimator_name} requires y to be passed, but the target y is None"
#    1261     )
# -> 1263 X = check_array(
#    1264     X,
#    1265     accept_sparse=accept_sparse,
#    1266     accept_large_sparse=accept_large_sparse,
#    1267     dtype=dtype,
#    1268     order=order,
#    1269     copy=copy,
#    1270     force_all_finite=force_all_finite,
#    1271     ensure_2d=ensure_2d,
#    1272     allow_nd=allow_nd,
#    1273     ensure_min_samples=ensure_min_samples,
#    1274     ensure_min_features=ensure_min_features,
#    1275     estimator=estimator,
#    1276     input_name="X",
#    1277 )
#    1279 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1281 check_consistent_length(X, y)
#
# File c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\sklearn\utils\validation.py:1072, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1070     n_samples = _num_samples(array)
#    1071     if n_samples < ensure_min_samples:
# -> 1072         raise ValueError(
#    1073             "Found array with %d sample(s) (shape=%s) while a"
#    1074             " minimum of %d is required%s."
#    1075             % (n_samples, array.shape, ensure_min_samples, context)
#    1076         )
#    1078 if ensure_min_features > 0 and array.ndim == 2:
#    1079     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0, 13)) while a minimum of 1 is required by RandomForestRegressor.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_log_error, r2_score, mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt


# 결측값 처리 (결측값이 있는 경우)
train = train.fillna(0)
test = test.fillna(0)

# 로그 변환 적용 (ECLO 컬럼)
train['ECLO'] = np.log1p(train['ECLO'])
test['ECLO'] = np.log1p(test['ECLO'])

# 사고 유형별로 데이터셋 분할 및 샘플링
train1 = train[train["사고유형"] == 2]  # 차량단독
train2 = train[train["사고유형"] == 1]  # 차대차
train3 = train[train["사고유형"] == 0]  # 차대사람

test1 = test[test["사고유형"] == 2]
test2 = test[test["사고유형"] == 1]
test3 = test[test["사고유형"] == 0]

# 데이터셋 분할 함수 정의
def split_data(df, target):
    X = df.drop(columns=[target])
    y = df[target]
    return X, y

X_train1, y_train1 = split_data(train1, 'ECLO')
X_train2, y_train2 = split_data(train2, 'ECLO')
X_train3, y_train3 = split_data(train3, 'ECLO')

X_test1, y_test1 = split_data(test1, 'ECLO')
X_test2, y_test2 = split_data(test2, 'ECLO')
X_test3, y_test3 = split_data(test3, 'ECLO')

# RMSLE 계산 함수 정의
def rmsle(y_true, y_pred):
    return np.sqrt(mean_squared_log_error(y_true, y_pred))

# 모델 학습 및 평가 함수 정의
def train_and_evaluate(X_train, y_train, X_test, y_test):
    model = RandomForestRegressor(random_state=42)
    model.fit(X_train, y_train)
    y_pred_test = model.predict(X_test)

    # 로그 역변환
    y_test_exp = np.expm1(y_test)
    y_pred_test_exp = np.expm1(y_pred_test)

    mse_value = mean_squared_error(y_test_exp, y_pred_test_exp)
    mae_value = mean_absolute_error(y_test_exp, y_pred_test_exp)
    rmsle_value = rmsle(y_test_exp, y_pred_test_exp)
    r2_value = r2_score(y_test_exp, y_pred_test_exp)

    return model, mse_value, mae_value, rmsle_value, r2_value

# 모델 학습 및 평가
model1, mse1, mae1, rmsle1, r21 = train_and_evaluate(X_train1, y_train1, X_test1, y_test1)
model2, mse2, mae2, rmsle2, r22 = train_and_evaluate(X_train2, y_train2, X_test2, y_test2)
model3, mse3, mae3, rmsle3, r23 = train_and_evaluate(X_train3, y_train3, X_test3, y_test3)

print(f'차량단독 사고 유형 - MSE: {mse1}, MAE: {mae1}, RMSLE: {rmsle1}, R²: {r21}')
print(f'차대차 사고 유형 - MSE: {mse2}, MAE: {mae2}, RMSLE: {rmsle2}, R²: {r22}')
print(f'차대사람 사고 유형 - MSE: {mse3}, MAE: {mae3}, RMSLE: {rmsle3}, R²: {r23}')

# 예측값을 test 데이터프레임에 추가
test1.loc[:, 'predict'] = np.expm1(model1.predict(X_test1))
test2.loc[:, 'predict'] = np.expm1(model2.predict(X_test2))
test3.loc[:, 'predict'] = np.expm1(model3.predict(X_test3))

# Feature Importance 시각화
def plot_feature_importance(model, X_train, title):
    importance = model.feature_importances_
    indices = np.argsort(importance)[::-1]
    plt.figure(figsize=(12, 6))
    plt.title(f'Feature Importance - {title}')
    plt.bar(range(X_train.shape[1]), importance[indices], align='center')
    plt.xticks(range(X_train.shape[1]), [X_train.columns[i] for i in indices], rotation=90)
    plt.tight_layout()
    plt.show()

plot_feature_importance(model1, X_train1, '차량단독 사고 유형')
plot_feature_importance(model2, X_train2, '차대차 사고 유형')
plot_feature_importance(model3, X_train3, '차대사람 사고 유형')

# RMSLE와 R² 값을 계산하여 출력
rmsle_test1 = rmsle(y_test1, test1['predict'])
r2_test1 = r2_score(y_test1, test1['predict'])
print(f'차량단독 사고 유형 (Test) - RMSLE: {rmsle_test1}, R²: {r2_test1}')

rmsle_test2 = rmsle(y_test2, test2['predict'])
r2_test2 = r2_score(y_test2, test2['predict'])
print(f'차대차 사고 유형 (Test) - RMSLE: {rmsle_test2}, R²: {r2_test2}')

rmsle_test3 = rmsle(y_test3, test3['predict'])
r2_test3 = r2_score(y_test3, test3['predict'])
print(f'차대사람 사고 유형 (Test) - RMSLE: {rmsle_test3}, R²: {r2_test3}')
# Out:
# 차량단독 사고 유형 - MSE: 4.6110733640445405, MAE: 1.4118419657493806, RMSLE: 0.42271725291909434, R²: -0.1269356907903929
# 차대차 사고 유형 - MSE: 12.70276629353593, MAE: 2.1082489286471615, RMSLE: 0.47254852066547115, R²: -0.12111367725896427
# 차대사람 사고 유형 - MSE: 3.6212566955498966, MAE: 1.2572532870719317, RMSLE: 0.3626583060811071, R²: -0.1327442054593997
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_22624\2224510483.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test1.loc[:, 'predict'] = np.expm1(model1.predict(X_test1))
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_22624\2224510483.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test2.loc[:, 'predict'] = np.expm1(model2.predict(X_test2))
# C:\Users\thdfy\AppData\Local\Temp\ipykernel_22624\2224510483.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test3.loc[:, 'predict'] = np.expm1(model3.predict(X_test3))
# 차량단독 사고 유형 (Test) - RMSLE: 0.6154604976461202, R²: -26.06481443576533
# 차대차 사고 유형 (Test) - RMSLE: 0.7332985601535423, R²: -45.838882418089774
# 차대사람 사고 유형 (Test) - RMSLE: 0.6331664055214483, R²: -41.97385828111346

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_log_error, r2_score
import matplotlib.pyplot as plt
import xgboost as xgb


# 결측값 처리 (결측값이 있는 경우)
train = train.fillna(0)
test = test.fillna(0)

# 사고 유형별로 데이터셋 분할
train1 = train[train["사고유형"] == 2]  # 차량단독
train2 = train[train["사고유형"] == 1]  # 차대차
train3 = train[train["사고유형"] == 0]  # 차대사람

test1 = test[test["사고유형"] == 2]  # 차량단독
test2 = test[test["사고유형"] == 1]  # 차대차
test3 = test[test["사고유형"] == 0]  # 차대사람

# 데이터셋 분할 함수 정의
def split_data(df, target):
    X = df.drop(columns=[target])
    y = df[target]
    return X, y

X_train1, y_train1 = split_data(train1, 'ECLO')
X_train2, y_train2 = split_data(train2, 'ECLO')
X_train3, y_train3 = split_data(train3, 'ECLO')

X_test1, y_test1 = split_data(test1, 'ECLO')
X_test2, y_test2 = split_data(test2, 'ECLO')
X_test3, y_test3 = split_data(test3, 'ECLO')

# RMSLE 계산 함수 정의
def rmsle(y_true, y_pred):
    return np.sqrt(mean_squared_log_error(y_true, y_pred))

# 모델 학습 및 평가 함수 정의
def train_and_evaluate(X_train, y_train, X_test, y_test):
    model = xgb.XGBRegressor(random_state=42)
    model.fit(X_train, y_train)
    y_pred_test = model.predict(X_test)

    rmsle_value = rmsle(y_test, y_pred_test)
    r2_value = r2_score(y_test, y_pred_test)

    return model, rmsle_value, r2_value

# 모델 학습 및 평가
model1, rmsle1, r21 = train_and_evaluate(X_train1, y_train1, X_test1, y_test1)
model2, rmsle2, r22 = train_and_evaluate(X_train2, y_train2, X_test2, y_test2)
model3, rmsle3, r23 = train_and_evaluate(X_train3, y_train3, X_test3, y_test3)

print(f'차량단독 사고 유형 - RMSLE: {rmsle1}, R²: {r21}')
print(f'차대차 사고 유형 - RMSLE: {rmsle2}, R²: {r22}')
print(f'차대사람 사고 유형 - RMSLE: {rmsle3}, R²: {r23}')

# 예측값을 test 데이터프레임에 추가
test1.loc[:, 'predict'] = model1.predict(X_test1)
test2.loc[:, 'predict'] = model2.predict(X_test2)
test3.loc[:, 'predict'] = model3.predict(X_test3)

# Feature Importance 시각화
def plot_feature_importance(model, X_train, title):
    importance = model.feature_importances_
    indices = np.argsort(importance)[::-1]
    plt.figure(figsize=(12, 6))
    plt.title(f'Feature Importance - {title}')
    plt.bar(range(X_train.shape[1]), importance[indices], align='center')
    plt.xticks(range(X_train.shape[1]), [X_train.columns[i] for i in indices], rotation=90)
    plt.tight_layout()
    plt.show()

plot_feature_importance(model1, X_train1, '차량단독 사고 유형')
plot_feature_importance(model2, X_train2, '차대차 사고 유형')
plot_feature_importance(model3, X_train3, '차대사람 사고 유형')

# RMSLE와 R² 값을 계산하여 출력
rmsle_test1 = rmsle(y_test1, test1['predict'])
r2_test1 = r2_score(y_test1, test1['predict'])
print(f'차량단독 사고 유형 (Test) - RMSLE: {rmsle_test1}, R²: {r2_test1}')

rmsle_test2 = rmsle(y_test2, test2['predict'])
r2_test2 = r2_score(y_test2, test2['predict'])
print(f'차대차 사고 유형 (Test) - RMSLE: {rmsle_test2}, R²: {r2_test2}')

rmsle_test3 = rmsle(y_test3, test3['predict'])
r2_test3 = r2_score(y_test3, test3['predict'])
print(f'차대사람 사고 유형 (Test) - RMSLE: {rmsle_test3}, R²: {r2_test3}')
# Out:
#   Cell In[436], line 20
#     test3 = test[test["사고유형"] == ]  # 차대사람
#                                  ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_squared_log_error, r2_score
import xgboost as xgb
import matplotlib.pyplot as plt


# 결측값 처리 (결측값이 있는 경우)
train = train.fillna(0)
test = test.fillna(0)

# 로그 변환 적용 (ECLO 컬럼)
train['ECLO'] = np.log1p(train['ECLO'])
test['ECLO'] = np.log1p(test['ECLO'])

# 사고 유형별로 데이터셋 분할 및 샘플링
train1 = train[train["사고유형"] == 2]  # 차량단독
train2 = train[train["사고유형"] == 1]  # 차대차
train3 = train[train["사고유형"] == 0]  # 차대사람

test1 = test[test["사고유형"] == 2]
test2 = test[test["사고유형"] == 1]
test3 = test[test["사고유형"] == 0]

# 데이터셋 분할 함수 정의
def split_data(df, target):
    X = df.drop(columns=[target])
    y = df[target]
    return X, y

X_train1, y_train1 = split_data(train1, 'ECLO')
X_train2, y_train2 = split_data(train2, 'ECLO')
X_train3, y_train3 = split_data(train3, 'ECLO')

X_test1, y_test1 = split_data(test1, 'ECLO')
X_test2, y_test2 = split_data(test2, 'ECLO')
X_test3, y_test3 = split_data(test3, 'ECLO')

# RMSLE 계산 함수 정의
def rmsle(y_true, y_pred):
    return np.sqrt(mean_squared_log_error(y_true, y_pred))

# XGBoost 모델 학습 및 평가 함수 정의
def train_and_evaluate(X_train, y_train, X_test, y_test):
    model = xgb.XGBRegressor(random_state=42)
    param_grid = {
        'n_estimators': [100, 200, 300],
        'learning_rate': [0.01, 0.05, 0.1],
        'max_depth': [3, 5, 7],
        'subsample': [0.7, 0.8, 0.9],
        'colsample_bytree': [0.7, 0.8, 0.9]
    }

    grid_search = GridSearchCV(estimator=model, param_grid=param_grid, scoring='rmsle', cv=5, n_jobs=-1)
    grid_search.fit(X_train, y_train)
    best_model = grid_search.best_estimator_
    y_pred_test = best_model.predict(X_test)

    # 로그 역변환
    y_test_exp = np.expm1(y_test)
    y_pred_test_exp = np.expm1(y_pred_test)

    mse_value = mean_squared_error(y_test_exp, y_pred_test_exp)
    mae_value = mean_absolute_error(y_test_exp, y_pred_test_exp)
    rmsle_value = rmsle(y_test_exp, y_pred_test_exp)
    r2_value = r2_score(y_test_exp, y_pred_test_exp)

    return best_model, mse_value, mae_value, rmsle_value, r2_value

# 모델 학습 및 평가
model1, mse1, mae1, rmsle1, r21 = train_and_evaluate(X_train1, y_train1, X_test1, y_test1)
model2, mse2, mae2, rmsle2, r22 = train_and_evaluate(X_train2, y_train2, X_test2, y_test2)
model3, mse3, mae3, rmsle3, r23 = train_and_evaluate(X_train3, y_train3, X_test3, y_test3)

print(f'차량단독 사고 유형 - MSE: {mse1}, MAE: {mae1}, RMSLE: {rmsle1}, R²: {r21}')
print(f'차대차 사고 유형 - MSE: {mse2}, MAE: {mae2}, RMSLE: {rmsle2}, R²: {r22}')
print(f'차대사람 사고 유형 - MSE: {mse3}, MAE: {mae3}, RMSLE: {rmsle3}, R²: {r23}')

# 예측값을 test 데이터프레임에 추가
test1.loc[:, 'predict'] = np.expm1(model1.predict(X_test1))
test2.loc[:, 'predict'] = np.expm1(model2.predict(X_test2))
test3.loc[:, 'predict'] = np.expm1(model3.predict(X_test3))

# Feature Importance 시각화
def plot_feature_importance(model, X_train, title):
    importance = model.feature_importances_
    indices = np.argsort(importance)[::-1]
    plt.figure(figsize=(12, 6))
    plt.title(f'Feature Importance - {title}')
    plt.bar(range(X_train.shape[1]), importance[indices], align='center')
    plt.xticks(range(X_train.shape[1]), [X_train.columns[i] for i in indices], rotation=90)
    plt.tight_layout()
    plt.show()

plot_feature_importance(model1, X_train1, '차량단독 사고 유형')
plot_feature_importance(model2, X_train2, '차대차 사고 유형')
plot_feature_importance(model3, X_train3, '차대사람 사고 유형')

# RMSLE와 R² 값을 계산하여 출력
rmsle_test1 = rmsle(y_test1, test1['predict'])
r2_test1 = r2_score(y_test1, test1['predict'])
print(f'차량단독 사고 유형 (Test) - RMSLE: {rmsle_test1}, R²: {r2_test1}')

rmsle_test2 = rmsle(y_test2, test2['predict'])
r2_test2 = r2_score(y_test2, test2['predict'])
print(f'차대차 사고 유형 (Test) - RMSLE: {rmsle_test2}, R²: {r2_test2}')

rmsle_test3 = rmsle(y_test3, test3['predict'])
r2_test3 = r2_score(y_test3, test3['predict'])
print(f'차대사람 사고 유형 (Test) - RMSLE: {rmsle_test3}, R²: {r2_test3}')
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[384], line 72
#      69     return best_model, mse_value, mae_value, rmsle_value, r2_value
#      71 # 모델 학습 및 평가
# ---> 72 model1, mse1, mae1, rmsle1, r21 = train_and_evaluate(X_train1, y_train1, X_test1, y_test1)
#      73 model2, mse2, mae2, rmsle2, r22 = train_and_evaluate(X_train2, y_train2, X_test2, y_test2)
#      74 model3, mse3, mae3, rmsle3, r23 = train_and_evaluate(X_train3, y_train3, X_test3, y_test3)
#
# Cell In[384], line 56, in train_and_evaluate(X_train, y_train, X_test, y_test)
#      47 param_grid = {
#      48     'n_estimators': [100, 200, 300],
#      49     'learning_rate': [0.01, 0.05, 0.1],
#    (...)
#      52     'colsample_bytree': [0.7, 0.8, 0.9]
#      53 }
#      55 grid_search = GridSearchCV(estimator=model, param_grid=param_grid, scoring='rmsle', cv=5, n_jobs=-1)
# ---> 56 grid_search.fit(X_train, y_train)
#      57 best_model = grid_search.best_estimator_
#      58 y_pred_test = best_model.predict(X_test)
#
# File c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\sklearn\base.py:1467, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1462 partial_fit_and_fitted = (
#    1463     fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1464 )
#    1466 if not global_skip_validation and not partial_fit_and_fitted:
# -> 1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
#    1474     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\sklearn\base.py:666, in BaseEstimator._validate_params(self)
#     658 def _validate_params(self):
#     659     """Validate types and values of constructor parameters
#     660
#     661     The expected type and values must be defined in the `_parameter_constraints`
#    (...)
#     664     accepted constraints.
#     665     """
# --> 666     validate_parameter_constraints(
#     667         self._parameter_constraints,
#     668         self.get_params(deep=False),
#     669         caller_name=self.__class__.__name__,
#     670     )
#
# File c:\Users\thdfy\anaconda3\envs\py310\lib\site-packages\sklearn\utils\_param_validation.py:95, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      89 else:
#      90     constraints_str = (
#      91         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      92         f" {constraints[-1]}"
#      93     )
# ---> 95 raise InvalidParameterError(
#      96     f"The {param_name!r} parameter of {caller_name} must be"
#      97     f" {constraints_str}. Got {param_val!r} instead."
#      98 )
#
# InvalidParameterError: The 'scoring' parameter of GridSearchCV must be a str among {'recall_micro', 'precision', 'neg_mean_squared_error', 'top_k_accuracy', 'neg_mean_absolute_percentage_error', 'jaccard', 'homogeneity_score', 'recall_weighted', 'accuracy', 'roc_auc_ovo', 'recall', 'adjusted_rand_score', 'positive_likelihood_ratio', 'neg_mean_poisson_deviance', 'adjusted_mutual_info_score', 'jaccard_macro', 'f1_weighted', 'max_error', 'neg_root_mean_squared_error', 'neg_negative_likelihood_ratio', 'precision_micro', 'balanced_accuracy', 'neg_median_absolute_error', 'neg_root_mean_squared_log_error', 'recall_macro', 'roc_auc_ovr', 'neg_brier_score', 'jaccard_samples', 'roc_auc_ovo_weighted', 'v_measure_score', 'jaccard_micro', 'mutual_info_score', 'neg_mean_squared_log_error', 'jaccard_weighted', 'average_precision', 'f1', 'f1_micro', 'r2', 'f1_samples', 'recall_samples', 'precision_weighted', 'matthews_corrcoef', 'precision_macro', 'neg_mean_gamma_deviance', 'normalized_mutual_info_score', 'neg_log_loss', 'rand_score', 'roc_auc_ovr_weighted', 'precision_samples', 'f1_macro', 'fowlkes_mallows_score', 'roc_auc', 'explained_variance', 'neg_mean_absolute_error', 'completeness_score'}, a callable, an instance of 'list', an instance of 'tuple', an instance of 'dict' or None. Got 'rmsle' instead.

# %%
test1[['ECLO','predict']]
# Out:
#            ECLO   predict
# 10     0.869742  1.440047
# 13     0.869742  1.443601
# 17     0.869742  1.450691
# 59     1.194706  1.441010
# 79     0.869742  1.447768
# ...         ...       ...
# 33476  1.026672  1.428364
# 33489  0.526589  1.436643
# 33518  0.869742  1.455212
# 33620  0.869742  1.429624
# 33641  1.026672  1.437083
#
# [1020 rows x 2 columns]

# %%
train['ECLO'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         3
# 1        10
# 2         1
# 3         6
# 4         5
#          ..
# 33693     3
# 33694     3
# 33695     1
# 33696     3
# 33697     6
# Name: ECLO, Length: 33698, dtype: int64>

# %%
test1[['ECLO','predict']]
test2[['ECLO','predict']]
test3[['ECLO','predict']]
# Out:
#        ECLO   predict
# 10        3  4.068886
# 13        3  3.336643
# 17        3  2.402504
# 59        9  4.139050
# 79        3  3.772724
# ...     ...       ...
# 33476     5  3.326353
# 33489     1  4.162469
# 33518     3  3.289004
# 33620     3  4.538691
# 33641     5  4.353229
#
# [1020 rows x 2 columns]

# %%
import numpy as np
from sklearn.metrics import mean_squared_log_error, r2_score

# 실제 값과 예측 값
y_true = np.array([1, 10, 100, 1000, 10000])
y_pred = np.array([10, 20, 30, 40, 50])  # 예측값이 실제값과 크게 차이나도록 설정

# RMSLE 계산
rmsle_value = np.sqrt(mean_squared_log_error(y_true, y_pred))

# R² 계산
r2_value = r2_score(y_true, y_pred)

print(f'RMSLE: {rmsle_value}')
print(f'R²: {r2_value}')
# Out:
# RMSLE: 2.9254857623854145
# R²: -0.30935770835695786

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# ECLO 분포 히스토그램
plt.figure(figsize=(12, 6))
sns.histplot(train['ECLO'], bins=30, kde=True)
plt.title('ECLO 분포 히스토그램')
plt.xlabel('ECLO')
plt.ylabel('빈도수')
plt.show()

# ECLO 분포 박스 플롯
plt.figure(figsize=(12, 6))
sns.boxplot(x=train['ECLO'])
plt.title('ECLO 분포 박스 플롯')
plt.xlabel('ECLO')
plt.show()

# %%
train1 = train[train["사고유형"] == 2]  # 차량단독
train2 = train[train["사고유형"] == 1]  # 차대차
train3 = train[train["사고유형"] == 0]  # 차대사람

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# ECLO 분포 히스토그램
plt.figure(figsize=(12, 6))
sns.histplot(train['ECLO'], bins=30, kde=True)
plt.title('ECLO 분포 히스토그램')
plt.xlabel('ECLO')
plt.ylabel('빈도수')
plt.show()

# ECLO 분포 박스 플롯
plt.figure(figsize=(12, 6))
sns.boxplot(x=train['ECLO'])
plt.title('ECLO 분포 박스 플롯')
plt.xlabel('ECLO')
plt.show()
